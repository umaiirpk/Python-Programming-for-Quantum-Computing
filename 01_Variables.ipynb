# %% [markdown]
# # First Code in programming language:
# Hello World!

# %%
print("Hello World!") # This print function will give Hello World! as output.
# Out:
# Hello World!

# %% [markdown]
# ## Python as Calculator

# %%
2+5 # Addition Operator + will add two numbers
# Out:
# 7

# %%
5-2 # Difference operator - will subtract two numbers
# Out:
# 3

# %%
5*2 # Multiplication operator *
# Out:
# 10

# %%
5/2 # Division Operator /
# Out:
# 2.5

# %%
6/2
# Out:
# 3.0

# %%
5%2 # Moduls operator % will return the remainder
# Out:
# 1

# %%
6%2
# Out:
# 0

# %%
5**5 # to rais a number to a certain power or exponent we use **
# Out:
# 3125
